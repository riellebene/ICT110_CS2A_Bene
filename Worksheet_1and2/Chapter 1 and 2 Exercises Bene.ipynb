# %%
print('Hello world!')
# Out:
# Hello world!

# %%
x = 6
print(x)
# Out:
# 6

# %%
x = 6
y = x * 7
print(y)
# Out:
# 42

# %% [markdown]
# Exercise 1

# %%
print('Hello world!') #the 'print' should not be capitalized
# Out:
# Hello world!

# %%
print('Hello world!') #missing an " ( "
# Out:
# Hello world!

# %%
print('Hello world!') #missing a closing " ' "
# Out:
# Hello world!

# %%
print('Hello world!') #added another closing ' causing to error
# Out:
# Hello world!

# %% [markdown]
# Excercise 2

# %% [markdown]
# What is the output of the code below? [PEW]

# %%
x = 43
x = x + 1
print(x)  #the answer is 44
# Out:
# 44

# %% [markdown]
# Exercise 3

# %%
x = 43
x = x + 1
print(x) #the x in x = x + 1 is in capital letter
# Out:
# 44

# %% [markdown]
# CHAPTER 2

# %%
print(2)
# Out:
# 2

# %%
'Hello world!'

# %%
print('Hello World')
# Out:
# Hello World

# %%
type('Hello, World!')
# Out:
# str

# %%
type(3.2)
# Out:
# float

# %%
type(17)
# Out:
# int

# %%
type('3.2')
# Out:
# str

# %%
print(1,000,000)
# Out:
# 1 0 0

# %%
print('1,000,000')
# Out:
# 1,000,000

# %%
x = 12.2
print(x) #print(x) should be placed in another line for it to run
# Out:
# 12.2

# %%
y = 14
print(y) #y should be print(y) and should be placed in another line for it to run
# Out:
# 14

# %%
x = 100
print(x) #x should be print(x) and should be placed in another line for it to run
# Out:
# 100

# %%
x1q3z9ocd = 35.0
x1q3z9afd = 12.50
x1q3p9afd = x1q3z9ocd * x1q3z9afd
print(x1q3p9afd)
# Out:
# 437.5

# %%
a = 35.0
b = 12.50
c = a * b
print(c)

# %%
5
# Out:
# 5

# %%
x = 5

# %%
x = 0.6
x
# Out:
# 0.6

# %%
x = 3.9 *  x  * ( 1  -  x )
x
# Out:
# 0.9359999999999999

# %%
print(x)
# Out:
# 0.9359999999999999

# %%
5 + 2
# Out:
# 7

# %%
5 - 2
# Out:
# 3

# %%
5 * 2
# Out:
# 10

# %%
5/2
# Out:
# 2.5

# %%
5 // 2
# Out:
# 2

# %%
5 % 2
# Out:
# 1

# %%
5**2
# Out:
# 25

# %%
x = 3.9 *  x  * ( 1  -  x )
x
# Out:
# 0.2336256000000002

# %%
d = 1 + 4
d
# Out:
# 5

# %%
e = 'hello ' + 'there'
e
# Out:
# 'hello there'

# %%
e = 'hello ' + 'there'
e = e + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-656f97e6ae3b> in <cell line: 2>()
#       1 e = 'hello ' + 'there'
# ----> 2 e = e + 1
#       3 type(e)
#       4 type(1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
type(e)
type(1)
# Out:
# int

# %% [markdown]
# Exercise 1

# %%
name = input('Enter your name: ')
print('Hello',name)
# Out:
# Enter your name: Chuck
# Hello Chuck

# %% [markdown]
# Exercise 2

# %%
hours = input('Enter Hours: ')
hrs = int(hours)
rate = input('Enter Rate: ')
rt = float(rate)
pay = hrs * rt
print('Pay:', pay)
# Out:
# Enter Hours: 35
# Enter Rate: 2.75
# Pay: 96.25

# %% [markdown]
# Exercise 3

# %% [markdown]
# Exercise 4

# %%
num = input('Enter a number:')
nm = int(num)
sq = nm * nm
print('The square of the number is', sq)
# Out:
# Enter a number:3
# The square of the number is 9

# %%
width =  input('Width:')
height = input('Height:')
x = 1 + 2 * 5
print(type(wd))
print(type(hg))
print(type(x))
# Out:
# Width:2
# Height:3
# <class 'float'>
# <class 'float'>
# <class 'int'>
